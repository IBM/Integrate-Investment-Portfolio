# %% [markdown]
# ### Get an Access Token
# __Before Running__ : Enter Quovo username/password
#
# __After Running__: Copy the Access Token

# %%
#Get an Access Token

import requests
import json

Quovo_username = "raheel.zubairy@gmail.com"
Quovo_password = "Shareable!@#123"

print ("Get Quovo Access Token")
BASEURL = "https://api.quovo.com/v2/tokens"
headers = {
    'Content-Type': "application/json"
    }
data = {
    'name': "main_token"
    }

get_data = requests.post(BASEURL, auth=(Quovo_username, Quovo_password), headers=headers, data=json.dumps(data))

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Get Quovo Access Token
# {
#     "access_token": {
#         "created": "2017-08-14T22:14:45Z",
#         "expires": "2017-08-14T23:14:44Z",
#         "name": "main_token",
#         "token": "0663ccbbd4da0c2b4882edb49dcfaf4ea1a9eae30048592daea95f220f7e60e8"
#     }
# }

# %% [markdown]
# ### Create User
# __Before Running__ : Paste the Access Token, Enter name, email
#
# __After Running__: Copy the User ID

# %%
#Create user

Token = "0663ccbbd4da0c2b4882edb49dcfaf4ea1a9eae30048592daea95f220f7e60e8"

print ("Create User")
BASEURL = "https://api.quovo.com/v2/users"
headers = {
    'Authorization': "Bearer " + Token,
    'Content-Type': "application/json"
    }
data = {
    'username': "main_token",
    'name': "xxx",
    'email': "xxx@xxx.com"
    }

get_data = requests.post(BASEURL, headers=headers, data=json.dumps(data))

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Create User
# {
#     "id": "user_limit_exceeded",
#     "message": "You have exceeded your maximum number of users.",
#     "status": 403
# }

# %% [markdown]
# ### Create Account
# __Before Running__ : Enter User ID, Enter Brokerage ID (look up in brokerages.json), Enter brokerage username/password
#
# __After Running__: Copy the Account ID

# %%
# Create account

User_ID = "2135739"

#test account
Brokerage_ID = 21534

print ("Create account")
BASEURL = "https://api.quovo.com/v2/users/" + User_ID + "/accounts"
headers = {
    'Authorization': "Bearer " + Token,
    'Content-Type': "application/json"
    }
data = {
    'brokerage': Brokerage_ID,
    'username': "testusername",
    'password': "testpass"
    }

get_data = requests.post(BASEURL, headers=headers, data=json.dumps(data))

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Create account
# {'account': {'username': 'main_token', 'status': None, 'updated': '2017-08-14T18:16:07.853', 'is_inactive': False, 'opened': '2017-08-14T18:16:07.853', 'last_good_sync': None, 'config_instructions': None, 'is_auth': False, 'value': None, 'failures': 0, 'brokerage_name': 'Test Data Brokerage', 'user': 2135739, 'update_count': 0, 'brokerage': 21534, 'nickname': None, 'id': 3402628}}

# %% [markdown]
# ### Sync Account
# __Before Running__ : Enter Account ID
#
# __After Running__: Ensure status is "syncing"

# %%
#Sync account

Account_ID = "3402628"

print ("Sync account")
BASEURL = "https://api.quovo.com/v2/accounts/" + Account_ID + "/sync"

headers = {
    'Authorization': "Bearer " + Token
    }

get_data = requests.post(BASEURL, headers=headers)

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Sync account
# {
#     "sync": {
#         "account": 3402628,
#         "has_realtime": false,
#         "progress": {
#             "message": "queued",
#             "percent": 0.0,
#             "state": "queued"
#         },
#         "status": "syncing"
#     }
# }

# %% [markdown]
# ### Check Sync
# __After Running__: Run till status is "good"

# %%
# Check sync till status: good

print ("Check Sync")
BASEURL = "https://api.quovo.com/v2/accounts/" + Account_ID + "/sync"

headers = {
    'Authorization': "Bearer " + Token
    }

get_data = requests.get(BASEURL, headers=headers)

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Check Sync
# {
#     "sync": {
#         "account": 3402628,
#         "has_realtime": false,
#         "progress": null,
#         "status": "good"
#     }
# }

# %% [markdown]
# ### Get Portfolios
# __After Running__: Creates portfolios.json, Copy Portfolio ID

# %%
# Get Portfolios

print ("Get Portfolios")
BASEURL = "https://api.quovo.com/v2/accounts/" + Account_ID + "/portfolios"

headers = {
    'Authorization': "Bearer " + Token
    }
get_data = requests.get(BASEURL, headers=headers)

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))

json_data = json.dumps(data)
f = open("portfolios.json", "w")
f.write(json_data)
f.close()
# Out:
# Get Portfolios
# {
#     "portfolios": [
#         {
#             "account": 3402628,
#             "brokerage": 21534,
#             "brokerage_name": "Test Data Brokerage",
#             "description": null,
#             "id": 5402696,
#             "is_inactive": false,
#             "is_taxable": true,
#             "last_change": "2017-08-14T18:20:18.757",
#             "nickname": null,
#             "owner_type": "Individual Account",
#             "portfolio_category": "Investment",
#             "portfolio_name": "***3582",
#             "portfolio_type": "Brokerage Account",
#             "portfolio_type_confidence": "Moderate",
#             "update_count": 1,
#             "user": 2135739,
#             "username": "main_token",
#             "value": 104075.1978
#         }
#     ]
# }

# %% [markdown]
# ### Get Portfolio Positions
# __Before Running__ : Enter Portfolio ID
#
# __After Running__: Creates positions.json

# %%
Portfolio_ID = "5402696"
print ("Get Positions of Portfolio")
BASEURL = "https://api.quovo.com/v2/portfolios/" + Portfolio_ID + "/positions"

headers = {
    'Authorization': "Bearer " + Token
    }
get_data = requests.get(BASEURL, headers=headers)

#print json data
data = get_data.json()
print (json.dumps(data, indent=4, sort_keys=True))

json_data = json.dumps(data)
f = open("positions.json", "w")
f.write(json_data)
f.close()
# Out:
# Get Positions of Portfolio
# {
#     "positions": [
#         {
#             "account": 3402628,
#             "asset_class": "Micro Cap Equity",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "046265104",
#             "fxrate": 1.0,
#             "id": 287025518,
#             "last_purchase_date": "2017-06-02",
#             "market_code": "NYE",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 19.24,
#             "quantity": 463.0,
#             "sector": null,
#             "security_type": "Equity",
#             "security_type_confidence": "Very High",
#             "ticker": "AF",
#             "ticker_name": "Astoria Financial Corporation",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 8908.12
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Micro Cap Equity",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "124830100",
#             "fxrate": 1.0,
#             "id": 287025519,
#             "last_purchase_date": "2017-07-11",
#             "market_code": "NYE",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 8.4,
#             "quantity": 1805.0,
#             "sector": "Real Estate",
#             "security_type": "Equity",
#             "security_type_confidence": "Very High",
#             "ticker": "CBL",
#             "ticker_name": "CBL & Associates Properties Inc.",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 15162.0
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Mid Cap Equity",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "422806109",
#             "fxrate": 1.0,
#             "id": 287025520,
#             "last_purchase_date": "2017-07-03",
#             "market_code": "NYE",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 85.94,
#             "quantity": 196.48,
#             "sector": null,
#             "security_type": "Equity",
#             "security_type_confidence": "Very High",
#             "ticker": "HEI",
#             "ticker_name": "Heico Corporation",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 16885.4912
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Mid Cap Equity",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "984121608",
#             "fxrate": 1.0,
#             "id": 287025521,
#             "last_purchase_date": "2017-05-30",
#             "market_code": "NYE",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 31.66,
#             "quantity": 450.51,
#             "sector": "Technology",
#             "security_type": "Equity",
#             "security_type_confidence": "Very High",
#             "ticker": "XRX",
#             "ticker_name": "Xerox Corporation",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 14263.1466
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Large Cap Equity",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "136385101",
#             "fxrate": 1.0,
#             "id": 287025522,
#             "last_purchase_date": "2017-08-02",
#             "market_code": "NYE",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 31.2,
#             "quantity": 287.0,
#             "sector": null,
#             "security_type": "Equity",
#             "security_type_confidence": "Very High",
#             "ticker": "CNQ",
#             "ticker_name": "Canadian Natural Resources Limited",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 8954.4
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Micro Cap Equity",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "737010108",
#             "fxrate": 1.0,
#             "id": 287025523,
#             "last_purchase_date": "2017-06-01",
#             "market_code": "NSD",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 55.68,
#             "quantity": 113.0,
#             "sector": "Healthcare",
#             "security_type": "Equity",
#             "security_type_confidence": "Very High",
#             "ticker": "PTLA",
#             "ticker_name": "Portola Pharmaceuticals Inc.",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 6291.84
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Emerging Market Bond ETFs",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "464286285",
#             "fxrate": 1.0,
#             "id": 287025524,
#             "last_purchase_date": "2017-06-02",
#             "market_code": "NYE",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 50.13,
#             "quantity": 160.0,
#             "sector": null,
#             "security_type": "ETF",
#             "security_type_confidence": "Very High",
#             "ticker": "EMHY",
#             "ticker_name": "iShares Emerging Markets High Yield Bond",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 8020.8
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Large Cap ETFs",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "99UBA3A15",
#             "fxrate": 1.0,
#             "id": 287025525,
#             "last_purchase_date": "2017-06-21",
#             "market_code": "NSD",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 142.1,
#             "quantity": 10.0,
#             "sector": null,
#             "security_type": "ETF",
#             "security_type_confidence": "Very High",
#             "ticker": "QQQ",
#             "ticker_name": "PowerShares QQQ Trust Series 1",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 1421.0
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Mutual Fund: Allocation Balanced",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": "694289422",
#             "fxrate": 1.0,
#             "id": 287025526,
#             "last_purchase_date": "2017-07-26",
#             "market_code": "NMF",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 12.36,
#             "quantity": 1648.0,
#             "sector": null,
#             "security_type": "Mutual Fund",
#             "security_type_confidence": "Very High",
#             "ticker": "POBCX",
#             "ticker_name": "Pacific Funds Portfolio Optimization Moderate-Conservative",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 20369.28
#         },
#         {
#             "account": 3402628,
#             "asset_class": "Cash",
#             "cost_basis": null,
#             "cost_basis_type": null,
#             "currency": null,
#             "cusip": null,
#             "fxrate": 1.0,
#             "id": 287025527,
#             "last_purchase_date": null,
#             "market_code": "CUR",
#             "portfolio": 5402696,
#             "portfolio_name": "***3582",
#             "price": 1.0,
#             "quantity": 3799.12,
#             "sector": null,
#             "security_type": "Cash",
#             "security_type_confidence": "Very High",
#             "ticker": "CUR:USD",
#             "ticker_name": "U S Dollar",
#             "user": 2135739,
#             "username": "main_token",
#             "value": 3799.12
#         }
#     ]
# }

# %% [markdown]
# ### Load Investment Portfolio service with Portfolio
# __Before Running__ : Enter Investment Portfolio credentials
#
# __After Running__: Creates portfolio with portfolio_name as name

# %%
import datetime

print ("Load Investment Portfolio")

IP_W_username="standedinstorwaytooddele"
IP_W_password="6340e126035f85d4913ee982b0d4e986a55a90ee"
IP_R_username="aitheirstainetiongirsell"
IP_R_password="5231860feb85f2c6c7ce38803d14639a2f2cd8bf"

with open('portfolios.json') as data_file:
    portfolios_json_data = json.load(data_file)

for portfolios in portfolios_json_data['portfolios']:
    print ("Add portfolio to service")
    timestamp = '{:%Y-%m-%dT%H:%M:%S.%fZ}'.format(datetime.datetime.now())
    
    BASEURL = "https://investment-portfolio.mybluemix.net/api/v1/portfolios"
    headers = {
        'Content-Type': "application/json",
        'Accept': "application/json"
        }
    data = {
        'name': portfolios['portfolio_name'],
        'timestamp': timestamp,
        'closed': False,
        'data': { 'manager': portfolios['brokerage_name'] }
        }

    get_data = requests.post(BASEURL, auth=(IP_W_username, IP_W_password), headers=headers, data=json.dumps(data))

    status = get_data.status_code
    print("Investment Portfolio status: " + str(status))

    #if the status is not success, return with status
    if status != 200:
        print(get_data)
    else:
        data = get_data.json()
        print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Load Investment Portfolio
# Add portfolio to service
# Investment Portfolio status: 200
# {
#     "_rev": "1-3f077909d960328f799f959ba35711b8"
# }

# %% [markdown]
# ### Load Investment Portfolio service with holdings/positions
# __Before Running__ : Enter account name
#
# __After Running__: Loads portfolio with positions/holdings

# %%
Portfolio = "***3582"

print ("Load Investment Portfolio Holdings")

with open('positions.json') as data_file:
    data = json.load(data_file)

holdings_data = []

for positions in data['positions']:
    position_data = {}

    if 'ticker' in positions:
        position_data["asset"] = positions['ticker']
    if 'quantity' in positions:
        position_data["quantity"] = positions['quantity']
    if 'ticker_name' in positions:
        position_data["companyName"] = positions['ticker_name']

    if 'asset_class' in positions:
        if positions['asset_class'] != 'Cash':
            holdings_data.append(position_data)

#print(holdings_data)
timestamp = '{:%Y-%m-%dT%H:%M:%S.%fZ}'.format(datetime.datetime.now())

BASEURL = "https://investment-portfolio.mybluemix.net/api/v1/portfolios/" + Portfolio + "/holdings"
headers = {
    'Content-Type': "application/json",
    'Accept': "application/json"
    }
data = {
    'timestamp': timestamp,
    'holdings': holdings_data,
    }

get_data = requests.post(BASEURL, auth=(IP_W_username, IP_W_password), headers=headers, data=json.dumps(data))

status = get_data.status_code
print("Investment Portfolio Holding status: " + str(status))

#if the status is not success, return with status
if status != 200:
    print(get_data)
else:
    data = get_data.json()
    print (json.dumps(data, indent=4, sort_keys=True))
# Out:
# Load Investment Portfolio Holdings
# Investment Portfolio Holding status: 200
# {
#     "_rev": "1-72dabc8c55ed5c8789e8795db3c07e8f"
# }
